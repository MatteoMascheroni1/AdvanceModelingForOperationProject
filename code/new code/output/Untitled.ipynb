# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./dataframe.csv")
for i in range(1,6):
    plt.plot(df["UL_in_buffer_"+str(i)], label = i)
plt.legend()
plt.show()

# %%
df.head(1)
# Out:
#    Time           Buffer  Tugger N  Tugger Capacity  Prod_1  UL_in_buffer_1  \
# 0     0  [3, 3, 3, 3, 3]         1                4       0               0
#
#    Idle_time_1  Prod_2  UL_in_buffer_2  Idle_time_2  ...  UL_in_buffer_3  \
# 0            0       0               0            0  ...               0
#
#    Idle_time_3  Prod_4  UL_in_buffer_4  Idle_time_4  Prod_5  UL_in_buffer_5  \
# 0            0       0               0            0       0               0
#
#    Idle_time_5  Saturation_1  Saturation_2
# 0            0         False         False
#
# [1 rows x 21 columns]

# %%
plt.plot(df["Idle_time_1"], label = '1')
plt.plot(df["Idle_time_2"], label = '2')
plt.show()
